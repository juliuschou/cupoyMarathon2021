# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 使用兩各隱藏層的情況下 hiden layer1=6, hiden layer2=2，Test Loss最低可以到 0.15

# %%
imgLayer=plt.imread("./Day_064_HW_Layer62.jpg") 
plt.figure(figsize=(15,15))
plt.imshow(imgLayer)
plt.title('layer1=6, layer2=2') 
plt.axis('off')
plt.show()

# %%
img=plt.imread("./Day_064_HW_Practice.jpg") 
fig2 = plt.figure(figsize=(15,15))
plt.imshow(img)
plt.title('Day 064 練習列表') 
plt.axis('off')
plt.show()
